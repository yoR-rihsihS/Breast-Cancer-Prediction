# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv('Data/data.csv')

# %%
print('Dataset Dimensions : ')
dataset.shape
# Out:
# Dataset Dimensions :
# (569, 33)

# %%
pd.set_option('display.max_columns', 50)
dataset.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
print('Totoal NaN values in Columns :')
dataset.isna().sum()
# Out:
# Totoal NaN values in Columns :
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# ...

# %%
dataset = dataset.dropna(axis=1)
dataset = dataset.drop(['id'], axis=1)

# %%
sns.set(style="ticks", color_codes=True)
g = sns.countplot(dataset['diagnosis'],label="Count", palette=['#FF6347','#90EE90'])

for p in g.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/len(dataset['diagnosis']))
        x = p.get_x() + p.get_width()/ 2 - 0.05
        y = p.get_y() + p.get_height() - 25
        g.annotate(percentage, (x, y), size = 12)
        
plt.show()

dataset['diagnosis'].value_counts()
# Out:
# D:\source\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
dataset.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
# for i in ('radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean','concave points_mean','symmetry_mean','fractal_dimension_mean','radius_se','texture_se','perimeter_se','area_se','smoothness_se','compactness_se','concavity_se','concave points_se','symmetry_se','fractal_dimension_se','radius_worst','texture_worst','perimeter_worst','area_worst','smoothness_worst','compactness_worst','concavity_worst','concave points_worst','symmetry_worst','fractal_dimension_worst'):
#     plt.figure()
#     sns.set(style="ticks", color_codes=True)
#     dataset[i][dataset['diagnosis'] == 'M'].plot.hist(alpha=0.5, color='#FF6347', title=i)
#     dataset[i][dataset['diagnosis'] == 'B'].plot.hist(alpha=0.5, color='#90EE90', title=i)
#     plt.show()

# %%
# for i in ('radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean','concave points_mean','symmetry_mean','fractal_dimension_mean','radius_se','texture_se','perimeter_se','area_se','smoothness_se','compactness_se','concavity_se','concave points_se','symmetry_se','fractal_dimension_se','radius_worst','texture_worst','perimeter_worst','area_worst','smoothness_worst','compactness_worst','concavity_worst','concave points_worst','symmetry_worst','fractal_dimension_worst'):
#     plt.figure()
#     sns.set(style="ticks", color_codes=True)
#     dataset[i][dataset['diagnosis'] == 'M'].plot.kde(title=i, color='red')
#     dataset[i][dataset['diagnosis'] == 'B'].plot.kde(title=i, color='#90EE90')
#     plt.show()

# %%
# sns.set(style="ticks", color_codes=True)
# sns.pairplot(
#     dataset,
#     palette = ('red', 'green'),
#     hue="diagnosis",
#     x_vars = ['radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean','concave points_mean','symmetry_mean','fractal_dimension_mean','radius_se','texture_se','perimeter_se','area_se','smoothness_se','compactness_se','concavity_se','concave points_se','symmetry_se','fractal_dimension_se','radius_worst','texture_worst','perimeter_worst','area_worst','smoothness_worst','compactness_worst','concavity_worst','concave points_worst','symmetry_worst','fractal_dimension_worst'],
#     y_vars = ['radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean','concave points_mean','symmetry_mean','fractal_dimension_mean','radius_se','texture_se','perimeter_se','area_se','smoothness_se','compactness_se','concavity_se','concave points_se','symmetry_se','fractal_dimension_se','radius_worst','texture_worst','perimeter_worst','area_worst','smoothness_worst','compactness_worst','concavity_worst','concave points_worst','symmetry_worst','fractal_dimension_worst'],
# )
# plt.show()

# %%
# plt.figure(figsize=(25,25))
# sns.set(style="ticks", color_codes=True)
# h = sns.heatmap(dataset.iloc[:,1:31].corr(), annot = True, fmt='.0%')
# plt.show()

# %%
x = dataset.iloc[:,1:31].values
y = dataset.iloc[:,0].values

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
y = labelencoder.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(sampling_strategy='minority',random_state=0)
x_SMOTE, y_SMOTE = smote.fit_resample(x_train, y_train)

# %%
from imblearn.over_sampling import KMeansSMOTE
kmeanssmote = KMeansSMOTE(sampling_strategy='minority',random_state=0)
x_KMeansSMOTE, y_KMeansSMOTE = kmeanssmote.fit_resample(x_train, y_train)
# Out:
# D:\source\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:887: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 3072 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(

# %%
from imblearn.combine import SMOTETomek
smotetomek = SMOTETomek(sampling_strategy='minority',random_state=0)
x_SMOTETomek, y_SMOTETomek = smotetomek.fit_resample(x_train, y_train)

# %%
result_table = pd.DataFrame(columns=['classifiers', 'fpr','tpr','auc'])

# %% [markdown]
# ## Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
logistic_model = LogisticRegression(random_state = 0, solver='newton-cg')
logistic_model.fit(x_SMOTETomek, y_SMOTETomek)

y_predict = logistic_model.predict(x_test)

fpr, tpr, _ = metrics.roc_curve(y_test,  y_predict)
auc = metrics.roc_auc_score(y_test, y_predict)
result_table = result_table.append({'classifiers':'Logistic Regression',
                                        'fpr':fpr, 
                                        'tpr':tpr, 
                                        'auc':auc}, ignore_index=True)

cf_matrix = metrics.confusion_matrix(y_test,y_predict)
group_names = ['True -ve', 'False +ve','False -ve','True +ve']
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')

accuracy = (cf_matrix[0,0] + cf_matrix[1,1]) / sum(sum(cf_matrix))
print('Accuracy : ', accuracy)

sensitivity = cf_matrix[1,1] / (cf_matrix[1,1] + cf_matrix[1,0])
print('Sensitivity : ', sensitivity)
print('False Omission Rate : ', (1-sensitivity))

specificity = cf_matrix[0,0] / (cf_matrix[0,0] + cf_matrix[0,1])
print('Specificity : ', specificity)
print('False Discovery Rate : ', (1-specificity))

print('Matthews Correlation Coefficient : ', metrics.matthews_corrcoef(y_test, y_predict))
# Out:
# Accuracy :  0.9824561403508771
# Sensitivity :  0.9787234042553191
# False Omission Rate :  0.021276595744680882
# Specificity :  0.9850746268656716
# False Discovery Rate :  0.014925373134328401
# Matthews Correlation Coefficient :  0.9637980311209908

# %%
# output=pd.DataFrame(data={"Actual":y_test,"Prediction":y_predict})
# output.to_csv(path_or_buf="Data/lr.csv",index=False,quoting=3,sep=',')

# %% [markdown]
# ## K-nearest Neighbour Model

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

Ks = 25
mean_acc = np.zeros((Ks-1))
Y_PREDICT = []

for n in range(1,Ks): 
    knn_model = KNeighborsClassifier(n_neighbors = n).fit(x_KMeansSMOTE,y_KMeansSMOTE)
    y_predict = knn_model.predict(x_test)
    Y_PREDICT.append(y_predict)
    mean_acc[n-1] = metrics.accuracy_score(y_test, y_predict)
    
fpr, tpr, _ = metrics.roc_curve(y_test,  Y_PREDICT[mean_acc.argmax()])
auc = metrics.roc_auc_score(y_test, Y_PREDICT[mean_acc.argmax()])
result_table = result_table.append({'classifiers':'K-Nearest Neighbour',
                                        'fpr':fpr, 
                                        'tpr':tpr, 
                                        'auc':auc}, ignore_index=True)

cf_matrix = metrics.confusion_matrix(y_test, Y_PREDICT[mean_acc.argmax()])
group_names = ['True -ve', 'False +ve','False -ve','True +ve']
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')

accuracy = (cf_matrix[0,0] + cf_matrix[1,1]) / sum(sum(cf_matrix))
print("The best accuracy was", accuracy, "with k=", mean_acc.argmax()+1)

sensitivity = cf_matrix[1,1] / (cf_matrix[1,1] + cf_matrix[1,0])
print('Sensitivity : ', sensitivity)
print('False Omission Rate : ', (1-sensitivity))

specificity = cf_matrix[0,0] / (cf_matrix[0,0] + cf_matrix[0,1])
print('Specificity : ', specificity)
print('False Discovery Rate : ', (1-specificity))

print('Matthews Correlation Coefficient : ', metrics.matthews_corrcoef(y_test, y_predict))
# Out:
# The best accuracy was 0.9736842105263158 with k= 16
# Sensitivity :  0.9361702127659575
# False Omission Rate :  0.06382978723404253
# Specificity :  1.0
# False Discovery Rate :  0.0
# Matthews Correlation Coefficient :  0.9118992727752026

# %%
# output=pd.DataFrame(data={"Actual":y_test,"Prediction":y_predict})
# output.to_csv(path_or_buf="Data/knn.csv",index=False,quoting=3,sep=',')

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.svm import SVC
from sklearn import metrics
svc = SVC(kernel = 'linear', random_state = 0)
svc.fit(x_train, y_train)

y_predict = svc.predict(x_test)

fpr, tpr, _ = metrics.roc_curve(y_test,  y_predict)
auc = metrics.roc_auc_score(y_test, y_predict)
result_table = result_table.append({'classifiers':'SVM',
                                        'fpr':fpr, 
                                        'tpr':tpr, 
                                        'auc':auc}, ignore_index=True)

cf_matrix = metrics.confusion_matrix(y_test,y_predict)
group_names = ['True -ve', 'False +ve','False -ve','True +ve']
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')

accuracy = (cf_matrix[0,0] + cf_matrix[1,1]) / sum(sum(cf_matrix))
print('Accuracy : ', accuracy)

sensitivity = cf_matrix[1,1] / (cf_matrix[1,1] + cf_matrix[1,0])
print('Sensitivity : ', sensitivity)
print('False Omission Rate : ', (1-sensitivity))

specificity = cf_matrix[0,0] / (cf_matrix[0,0] + cf_matrix[0,1])
print('Specificity : ', specificity)
print('False Discovery Rate : ', (1-specificity))

print('Matthews Correlation Coefficient : ', metrics.matthews_corrcoef(y_test, y_predict))
# Out:
# Accuracy :  0.9824561403508771
# Sensitivity :  0.9787234042553191
# False Omission Rate :  0.021276595744680882
# Specificity :  0.9850746268656716
# False Discovery Rate :  0.014925373134328401
# Matthews Correlation Coefficient :  0.9637980311209908

# %%
# output=pd.DataFrame(data={"Actual":y_test,"Prediction":y_predict})
# output.to_csv(path_or_buf="Data/svm.csv",index=False,quoting=3,sep=',')

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
gnb = GaussianNB()
gnb.fit(x_KMeansSMOTE,y_KMeansSMOTE)

y_predict = gnb.predict(x_test)

fpr, tpr, _ = metrics.roc_curve(y_test,  y_predict)
auc = metrics.roc_auc_score(y_test, y_predict)
result_table = result_table.append({'classifiers':'Naive Bayes',
                                        'fpr':fpr, 
                                        'tpr':tpr, 
                                        'auc':auc}, ignore_index=True)

cf_matrix = metrics.confusion_matrix(y_test,y_predict)
group_names = ['True -ve', 'False +ve','False -ve','True +ve']
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')

accuracy = (cf_matrix[0,0] + cf_matrix[1,1]) / sum(sum(cf_matrix))
print('Accuracy : ', accuracy)

sensitivity = cf_matrix[1,1] / (cf_matrix[1,1] + cf_matrix[1,0])
print('Sensitivity : ', sensitivity)
print('False Omission Rate : ', (1-sensitivity))

specificity = cf_matrix[0,0] / (cf_matrix[0,0] + cf_matrix[0,1])
print('Specificity : ', specificity)
print('False Discovery Rate : ', (1-specificity))

print('Matthews Correlation Coefficient : ', metrics.matthews_corrcoef(y_test, y_predict))
# Out:
# Accuracy :  0.9210526315789473
# Sensitivity :  0.8723404255319149
# False Omission Rate :  0.12765957446808507
# Specificity :  0.9552238805970149
# False Discovery Rate :  0.04477611940298509
# Matthews Correlation Coefficient :  0.8367827577646452

# %%
# output=pd.DataFrame(data={"Actual":y_test,"Prediction":y_predict})
# output.to_csv(path_or_buf="Data/nb.csv",index=False,quoting=3,sep=',')

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
tree = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
tree.fit(x_SMOTE, y_SMOTE)

y_predict = tree.predict(x_test)

fpr, tpr, _ = metrics.roc_curve(y_test,  y_predict)
auc = metrics.roc_auc_score(y_test, y_predict)
result_table = result_table.append({'classifiers':'Decision Tree',
                                        'fpr':fpr, 
                                        'tpr':tpr, 
                                        'auc':auc}, ignore_index=True)

cf_matrix = metrics.confusion_matrix(y_test,y_predict)
group_names = ['True -ve', 'False +ve','False -ve','True +ve']
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')

accuracy = (cf_matrix[0,0] + cf_matrix[1,1]) / sum(sum(cf_matrix))
print('Accuracy : ', accuracy)

sensitivity = cf_matrix[1,1] / (cf_matrix[1,1] + cf_matrix[1,0])
print('Sensitivity : ', sensitivity)
print('False Omission Rate : ', (1-sensitivity))

specificity = cf_matrix[0,0] / (cf_matrix[0,0] + cf_matrix[0,1])
print('Specificity : ', specificity)
print('False Discovery Rate : ', (1-specificity))

print('Matthews Correlation Coefficient : ', metrics.matthews_corrcoef(y_test, y_predict))
# Out:
# Accuracy :  0.9736842105263158
# Sensitivity :  0.9787234042553191
# False Omission Rate :  0.021276595744680882
# Specificity :  0.9701492537313433
# False Discovery Rate :  0.02985074626865669
# Matthews Correlation Coefficient :  0.9460229589089657

# %%
# output=pd.DataFrame(data={"Actual":y_test,"Prediction":y_predict})
# output.to_csv(path_or_buf="Data/dt.csv",index=False,quoting=3,sep=',')

# %% [markdown]
# ## Random Forest Classifier (Ensemble Class)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
forest = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
forest.fit(x_train, y_train)

y_predict = forest.predict(x_test)

fpr, tpr, _ = metrics.roc_curve(y_test,  y_predict)
auc = metrics.roc_auc_score(y_test, y_predict)
result_table = result_table.append({'classifiers':'Random Forest',
                                        'fpr':fpr, 
                                        'tpr':tpr, 
                                        'auc':auc}, ignore_index=True)

cf_matrix = metrics.confusion_matrix(y_test,y_predict)
group_names = ['True -ve', 'False +ve','False -ve','True +ve']
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')

accuracy = (cf_matrix[0,0] + cf_matrix[1,1]) / sum(sum(cf_matrix))
print('Accuracy : ', accuracy)

sensitivity = cf_matrix[1,1] / (cf_matrix[1,1] + cf_matrix[1,0])
print('Sensitivity : ', sensitivity)
print('False Omission Rate : ', (1-sensitivity))

specificity = cf_matrix[0,0] / (cf_matrix[0,0] + cf_matrix[0,1])
print('Specificity : ', specificity)
print('False Discovery Rate : ', (1-specificity))

print('Matthews Correlation Coefficient : ', metrics.matthews_corrcoef(y_test, y_predict))
# Out:
# Accuracy :  0.9736842105263158
# Sensitivity :  0.9574468085106383
# False Omission Rate :  0.04255319148936165
# Specificity :  0.9850746268656716
# False Discovery Rate :  0.014925373134328401
# Matthews Correlation Coefficient :  0.9456799777237261

# %%
# output=pd.DataFrame(data={"Actual":y_test,"Prediction":y_predict})
# output.to_csv(path_or_buf="Data/rf.csv",index=False,quoting=3,sep=',')

# %%
result_table.set_index('classifiers', inplace=True)
fig = plt.figure(figsize=(10,10))
sns.set_style('darkgrid', {'axes.facecolor': '0.9'})

for i in result_table.index:
    plt.plot(result_table.loc[i]['fpr'], 
             result_table.loc[i]['tpr'], 
             label="{}, AUC={:.3f}".format(i, result_table.loc[i]['auc']))
    
plt.plot([0,1], [0,1], color='orange', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1))
plt.xlabel("Flase Positive Rate", fontsize=15)

plt.yticks(np.arange(0.0, 1.1, step=0.1))
plt.ylabel("True Positive Rate", fontsize=15)

plt.title('ROC Curve Analysis', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')

plt.show()
